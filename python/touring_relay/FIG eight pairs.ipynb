# %%
# %load_ext jupyternotify

import numpy as np
import matplotlib
#allow for latex markup in matplotlib figures
matplotlib.rcParams['text.usetex'] = False
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap


#Import a few utility functions...
import sys  
from pathlib import Path
sys.path.insert(0, "../comm_channel")
sys.path.insert(0, "../polling_systems")
sys.path.insert(0, "../geometry")
sys.path.insert(0, "../utils")

#So we can import my local libs
import CommChannel as CC
import qos
import pointcloud as PC
import TSPN
import PollingSystem as PS
import MarkovianRP as MRP
import dtr
import motion
import shot_solvers as SHOT

import sim_template as sim
from importlib import reload

# %%
#setup quality of service requirements using reasonable values
F5GHz, F2_4GHz = 5, 2.4 #typical wifi frequencies are 2.4, 5, and sometiems 6 GHz
MOBILE_TX_POWER = qos.Pwr(20)#100-200mW (20-23 dBm) pretty typical, with 1W (30dBm) the absolute maximum
print(MOBILE_TX_POWER)
r = 8#any of 2, 4, 6, or 8
rx_noise = qos.Pwr(-85)#based on Yan and MostofiTWC13 #1e-10#
print(rx_noise)
BER = 1e-6
GAMMA_TH = qos.QoSReq(BER, r, rx_noise).thresholdChannelGain(MOBILE_TX_POWER)
print(GAMMA_TH)
print('SNR Threshold: %d'%(GAMMA_TH+MOBILE_TX_POWER.dBm - rx_noise.dBm))
# Out:
# 20.000000 dBm	-10.000000 dBW	100.000000 mW	0.100000 W
# -85.000000 dBm	-115.000000 dBW	0.000000 mW	0.000000 W
# -71.8297512825111
# SNR Threshold: 33

# %%
#Setup the communication environment:

#For now, use same channel params
nPL = 5.2
kPL = -20

decorrSH = 2.09  
alpha = 16
sigmaSH = np.sqrt(alpha)
psdAtFC = 30

lam = 0.125
kRic = 10
decorrMP = 0.4*lam         
corrMP = 1
#sigmaMP = 3
sigmaMP = 1.5


#12 remote stations
l = 11
qBase = np.array([[2,6],[21,4],
                 [16,11],[28,23],
                 [10,22],[11,39],
                 [30, 11],[48, 8],
                 [18, 36],[35, 41],
                 [32, 33],[48, 25],
                 [2,43],[18, 49]])#,
#                  [38,36],[48, 48]])

sub_regions = [[25,0,10,0],
               [30,10, 25, 9],
               [20,0, 40, 17],
               [50, 25, 15, 3],
               [38, 15, 45, 27],
               [50, 30, 40, 20],
               [17,0, 50, 38]]#,
#                [50, 34, 50, 35]]


x_max = 50
x_min = 0
y_max = 50
y_min = 0
region = [x_max, x_min, y_max, y_min]


cps = [CC.ChannelParams(qBase[i], nPL, kPL, sigmaSH, decorrSH, decorrMP, lam,
                      kRic, corrMP, psdAtFC, sigmaMP) for i in range(len(qBase))]



#res = 2/decorrMP
res = 10
n = 7
p_th = 0.5

#Polling System Setup
bandwidth = 2#leave bandwidth in MHz*1000000#give ourselfes 2MHz of BW
beta = 1/(r*bandwidth)
print(beta)
els = [0.1/beta, 0.05/beta, 0.1/beta, 0.05/beta, 0.1/beta, 0.05/beta, 0.1/beta]#, 0.05/beta]
print(els)
# Out:
# 0.0625
# [1.6, 0.8, 1.6, 0.8, 1.6, 0.8, 1.6]

# %%
reload(sim)
ccs, cfs, true_joint_con_fields, tjcps = sim.create_channels(cps, region, res, GAMMA_TH, sub_regions)
# Out:
# Generating shadowing...
# Shadowing generation complete.
# Generating MP...
# MP generation complete.
# Generating shadowing...
# Shadowing generation complete.
# Generating MP...
# MP generation complete.
# Generating shadowing...
# Shadowing generation complete.
# Generating MP...
# MP generation complete.
# Generating shadowing...
# Shadowing generation complete.
# Generating MP...
# MP generation complete.
# Generating shadowing...
# Shadowing generation complete.
# Generating MP...
# MP generation complete.
# Generating shadowing...
# Shadowing generation complete.
# Generating MP...
# MP generation complete.
# Generating shadowing...
# Shadowing generation complete.
# Generating MP...
# MP generation complete.
# Generating shadowing...
# Shadowing generation complete.
# Generating MP...
# MP generation complete.
# Generating shadowing...
# Shadowing generation complete.
# Generating MP...
# MP generation complete.
# Generating shadowing...
# Shadowing generation complete.
# Generating MP...
# MP generation complete.
# Generating shadowing...
# Shadowing generation complete.
# Generating MP...
# MP generation complete.
# Generating shadowing...
# Shadowing generation complete.
# Generating MP...
# MP generation complete.
# Generating shadowing...
# Shadowing generation complete.
# Generating MP...
# MP generation complete.
# Generating shadowing...
# Shadowing generation complete.
# Generating MP...
# MP generation complete.

# %%
reload(sim)
pcs, pfs, pjcps, prob_pred_con = sim.predict_channels(res, ccs, true_joint_con_fields, GAMMA_TH, p_th=p_th)
trismall_pcs = pcs

print(prob_pred_con)
# Out:
# Drawing 250 samples from Channel 1
# Completed PredictedChannel 1
# Drawing 250 samples from Channel 2
# Completed PredictedChannel 2
# Drawing 320 samples from Channel 3
# Completed PredictedChannel 3
# Drawing 320 samples from Channel 4
# Completed PredictedChannel 4
# Drawing 460 samples from Channel 5
# Completed PredictedChannel 5
# Drawing 460 samples from Channel 6
# Completed PredictedChannel 6
# Drawing 300 samples from Channel 7
# Completed PredictedChannel 7
# Drawing 300 samples from Channel 8
# Completed PredictedChannel 8
# Drawing 414 samples from Channel 9
# Completed PredictedChannel 9
# Drawing 414 samples from Channel 10
# Completed PredictedChannel 10
# Drawing 400 samples from Channel 11
# Completed PredictedChannel 11
# Drawing 400 samples from Channel 12
# Completed PredictedChannel 12
# Drawing 204 samples from Channel 13
# Completed PredictedChannel 13
# Drawing 204 samples from Channel 14
# Completed PredictedChannel 14
# [0.6821008984105045, 0.7901897601145721, 0.7841011743450768, 0.7948369565217391, 0.7093963907902925, 0.756045820958846, 0.6213483146067416]

# %%
reload(sim)
sim.plotCFwithOverlay(n, tjcps, pjcps, qBase, region)
plt.gca().invert_yaxis()
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica

# %%
#setup the delay-tolerant relay system
reload(dtr)
dt_sys = dtr.DTR(pcs, region, els, beta, th=GAMMA_TH, p_th = p_th)
# Out:
# Extracted edges...
# Polygons constructed, looking for holes...
# Constructed 3 possibly non-convex polygons
# 10 total subregions
# Extracted edges...
# Polygons constructed, looking for holes...
# Constructed 2 possibly non-convex polygons
# 15 total subregions
# Extracted edges...
# Polygons constructed, looking for holes...
# Constructed 5 possibly non-convex polygons
# 19 total subregions
# Extracted edges...
# Polygons constructed, looking for holes...
# Constructed 2 possibly non-convex polygons
# 6 total subregions
# Extracted edges...
# Polygons constructed, looking for holes...
# Constructed 1 possibly non-convex polygons
# 8 total subregions
# Extracted edges...
# Polygons constructed, looking for holes...
# Constructed 2 possibly non-convex polygons
# 14 total subregions
# Extracted edges...
# Polygons constructed, looking for holes...
# Constructed 2 possibly non-convex polygons
# 12 total subregions

# %%
#Calculate baseline TSPN policy
# import gurobi_solvers as GB
# reload(GB)
reload(TSPN)
regions = dt_sys.cregions
tspn_min, tspn_argmin = TSPN.TSPN_BF(regions, (0, 1, 2, 6, 4, 5, 3))
x=tspn_argmin[0]

reload(sim)
order = list(tspn_argmin[1])
order.append(0)#complete the loop
sim.plotCFwithOverlay(n, tjcps, pjcps, qBase, region)
plt.plot(x[order,0], x[order,1], zorder=100)
plt.scatter(x[:,0], x[:,1], zorder = 100)
plt.gca().invert_yaxis()
plt.show()

tspn_argmin[1]
# Out:
# Total of 361 Permutations to Try
# Working on Permutation (0, 1, 2, 6, 4, 5, 3)
# Academic license - for non-commercial use only - expires 2022-07-30
# Using license file /opt/gurobi912/gurobi.lic

# %%
reload(dtr)
reload(sim)

vs=[0.5, 1, 2, 5]
AORPS=[]
for v in vs:
    AORPS.append(sim.calc_AORP(dt_sys, v))
# Out:
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 585.0000
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 578.3721
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 574.8749
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 576.5236
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 577.0723
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 577.0148
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 573.9147
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 573.8451
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 607.4761
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 574.9981
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 699.3999
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 576.3667
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 699.2892
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 575.8751
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 597.3590
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 575.0825
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 699.4000
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 584.0016
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 577.8111
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 698.7047
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 576.4134
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 577.0621
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 602.0008
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 580.0676
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 578.8404
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 598.4566
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 701.1201
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 576.3002
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 573.8477
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 616.2827
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 585.0629
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 700.6261
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 577.8516
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 575.1279
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 573.8477
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 578.5492
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 577.7315
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 573.9088
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 699.4001
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 599.5329
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 701.0423
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 581.3780
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 577.7315
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 577.0150
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 577.0148
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 300.8367
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 350.6036
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 299.8527
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="unknown";
#       - termination condition: optimal
#       - message from solver: SHOT\x3a Solved to local optimality
# Optimized Waiting Time: 289.0742

# %%
print(AORP)
reload(sim)
sim.plot_AORP(dt_sys, AORP, tjcps, pjcps, qBase, region)

# %%
# reload(SHOT)
# pi = AORP['pi']
# x = AORP['X']
# S = np.zeros((n,n))
# for i in range(n):
#     for j in range(n):
#         S[i,j] = np.linalg.norm(x[i] - x[j])

# print(pi)
# print(S)
# P, val = SHOT.min_PWD_over_P(pi, S, verbose = False)

# %%
# %%notify
# reload(sim)
# TSPNP={'X':x, 'SEQ':tspn_argmin[1]}
# hrs = 1
# mins = 0
# seconds = 0
# for i in range(len(vs)):
#     v = vs[i]
#     print('Velocity = %f'%(v))
#     AORP = AORPS[i]
#     motion_power = motion.LinearMotionPower(7.2, 0.29, v)
#     sim.run_sims(dt_sys.ps, AORP, TSPNP, hrs, mins, seconds, motion_power, MOBILE_TX_POWER.W, v)
